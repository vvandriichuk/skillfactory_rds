# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter
from itertools import combinations
print(os.listdir("input"))
# Out:
# ['data.csv']

# %%
data = pd.read_csv('input/data.csv')
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610        33.0  150000000  1513528810                Jurassic World
# 1  tt1392190        28.4  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446        13.1  110000000   295238201                     Insurgent
# 3  tt2488496        11.2  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852         9.3  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
len(data)
# Out:
# 1890

# %% [markdown]
# # Предобработка датасета

# %%
answer_ls = [] # создадим список с ответами. сюда будем добавлять ответы по мере прохождения теста
# сюда можем вписать создание новых колонок в датасете

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
data = pd.read_csv('input/data.csv')
display(data.sort_values(by=['budget'], ascending=False))

# тут вводим ваш ответ и добавлем в его список ответов (сейчас для примера стоит "1")
answer_ls.append(4)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 491   tt1032751         0.3  425000000    11087569
# 724   tt1298650         5.0  380000000  1021683000
# 1670  tt0449088         5.0  300000000   961000000
# 14    tt2395427         5.9  280000000  1405035767
# 1015  tt0401729         1.6  260000000   284139100
# ...         ...         ...        ...         ...
# 886   tt0283111         1.6    5000000    38275483
# 893   tt0259446         1.3    5000000   368744044
# 1072  tt2109184         0.6    5000000   142817992
# 912   tt0322802         0.9    5000000    64282312
# 1217  tt2101441         1.6    5000000    31724284
#
#                                    original_title  \
# 491                             The Warrior's Way
# 724   Pirates of the Caribbean: On Stranger Tides
# 1670     Pirates of the Caribbean: At World's End
# 14                        Avengers: Age of Ultron
# 1015                                  John Carter
# ...

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
display(data.sort_values(by=['runtime'], ascending=False))

answer_ls.append(2)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 1158  tt0279111         0.5   56000000    12923936
# 1082  tt0167260         7.1   94000000  1118888979
# 1737  tt0462322         0.9   67000000    25037897
# 1337  tt0360717         1.5  207000000   550000000
# 505   tt0213149         2.5  140000000   449220945
# ...         ...         ...        ...         ...
# 1627  tt0299172         0.8  110000000   103951461
# 1409  tt0361089         0.6   35000000    19478106
# 1098  tt0283426         1.8   20000000   135680000
# 931   tt0280030         0.7   20000000   109862682
# 769   tt1449283         1.4   30000000    14460000
#
#                                      original_title  \
# 1158                              Gods and Generals
# 1082  The Lord of the Rings: The Return of the King
# 1737                                     Grindhouse
# 1337                                      King Kong
# 505                                    Pearl Harbor
# ...

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
display(data.sort_values(by=['runtime'], ascending=True))

answer_ls.append(3)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 769   tt1449283         1.4   30000000    14460000
# 931   tt0280030         0.7   20000000   109862682
# 1098  tt0283426         1.8   20000000   135680000
# 1627  tt0299172         0.8  110000000   103951461
# 1409  tt0361089         0.6   35000000    19478106
# ...         ...         ...        ...         ...
# 505   tt0213149         2.5  140000000   449220945
# 1337  tt0360717         1.5  207000000   550000000
# 1737  tt0462322         0.9   67000000    25037897
# 1082  tt0167260         7.1   94000000  1118888979
# 1158  tt0279111         0.5   56000000    12923936
#
#                                      original_title  \
# 769                                 Winnie the Pooh
# 931                            Return to Never Land
# 1098                              The Jungle Book 2
# 1627                              Home on the Range
# 1409                                        Valiant
# ...

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
display(data['runtime'].mean())

answer_ls.append(2)
# Out:
# 109.65343915343915

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
display(data['runtime'].median())

answer_ls.append(1)
# Out:
# 106.5

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
data['profit'] = data.apply(lambda row: row.revenue - row.budget, axis = 1)

display(data.sort_values(by=['profit'], ascending=False))

answer_ls.append(5)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 239   tt0499549         9.4  237000000  2781505847
# 3     tt2488496        11.2  200000000  2068178225
# 0     tt0369610        33.0  150000000  1513528810
# 4     tt2820852         9.3  190000000  1506249360
# 971   tt0848228         7.6  220000000  1519557910
# ...         ...         ...        ...         ...
# 959   tt0180052         0.9  100000000     7103973
# 810   tt1305591         0.9  150000000    38992758
# 1617  tt0318974         0.9  145000000    25819961
# 1246  tt1210819         1.2  255000000    89289910
# 491   tt1032751         0.3  425000000    11087569
#
#                     original_title  \
# 239                         Avatar
# 3     Star Wars: The Force Awakens
# 0                   Jurassic World
# 4                        Furious 7
# 971                   The Avengers
# ...                            ...
# 959   The Adventures of Pluto Nash
# 810                Mars Needs Moms
# ...

# %% [markdown]
# # 7. Какой фильм самый убыточный?
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
data['profit'] = data.apply(lambda row: row.revenue - row.budget, axis = 1)

display(data.sort_values(by=['profit'], ascending=True))

answer_ls.append(2)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 491   tt1032751         0.3  425000000    11087569
# 1246  tt1210819         1.2  255000000    89289910
# 1617  tt0318974         0.9  145000000    25819961
# 810   tt1305591         0.9  150000000    38992758
# 959   tt0180052         0.9  100000000     7103973
# ...         ...         ...        ...         ...
# 971   tt0848228         7.6  220000000  1519557910
# 4     tt2820852         9.3  190000000  1506249360
# 0     tt0369610        33.0  150000000  1513528810
# 3     tt2488496        11.2  200000000  2068178225
# 239   tt0499549         9.4  237000000  2781505847
#
#                     original_title  \
# 491              The Warrior's Way
# 1246               The Lone Ranger
# 1617                     The Alamo
# 810                Mars Needs Moms
# 959   The Adventures of Pluto Nash
# ...                            ...
# 971                   The Avengers
# 4                        Furious 7
# ...

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
log2 = data.query('profit > 0').count()
display(log2)

answer_ls.append(1)
# Out:
# imdb_id                 1478
# popularity              1478
# budget                  1478
# revenue                 1478
# original_title          1478
# cast                    1478
# director                1478
# tagline                 1478
# overview                1478
# runtime                 1478
# genres                  1478
# production_companies    1478
# release_date            1478
# vote_count              1478
# vote_average            1478
# release_year            1478
# profit                  1478
# dtype: int64

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
log2 = data.query('release_year == 2008')
display(log2.sort_values(by=['profit'], ascending=False))


answer_ls.append(4)
# Out:
#        imdb_id  popularity     budget     revenue  \
# 600  tt0468569         8.5  185000000  1001921825
# 604  tt0367882         3.2  185000000   786636033
# 608  tt0795421         2.5   52000000   609841637
# 607  tt0441773         3.0  130000000   631744560
# 622  tt0448157         1.8  150000000   624029371
# ..         ...         ...        ...         ...
# 669  tt0811080         0.9  120000000    93945766
# 706  tt0469903         0.5   40000000     9793496
# 683  tt0970411         0.7   55000000    17869048
# 680  tt0462465         0.7   50000000     7033683
# 637  tt0455824         1.5  130000000    49554002
#
#                                         original_title  \
# 600                                    The Dark Knight
# 604  Indiana Jones and the Kingdom of the Crystal S...
# 608                                         Mamma Mia!
# 607                                      Kung Fu Panda
# 622                                            Hancock
# ...

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
log2 = data.query('2012 <= release_year <= 2014')
display(log2.sort_values(by=['profit'], ascending=True))

answer_ls.append(5)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 1246  tt1210819         1.2  255000000    89289910
# 1215  tt0790736         1.7  130000000    61648500
# 1008  tt1374992         1.7   60000000     8106475
# 1303  tt0884726         0.4   70000000    18662027
# 1236  tt1308729         1.3   55000000     9489829
# ...         ...         ...        ...         ...
# 1190  tt1690953         3.9   76000000   970761885
# 975   tt1074638         5.6  200000000  1108561013
# 1181  tt1300854         4.9  200000000  1215439994
# 1178  tt2294629         6.1  150000000  1274219009
# 971   tt0848228         7.6  220000000  1519557910
#
#                        original_title  \
# 1246                  The Lone Ranger
# 1215                         R.I.P.D.
# 1008                      Upside Down
# 1303  Legends of Oz: Dorothy's Return
# 1236               Bullet to the Head
# ...                               ...
# 1190                  Despicable Me 2
# ...

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
log3 = pd.DataFrame(data.genres.str.split('|').tolist()).stack().value_counts().head(1)
display(log3)

answer_ls.append(3)
# Out:
# Drama    782
# dtype: int64

# %% [markdown]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
log4 = data.query('profit > 0')
log4 = pd.DataFrame(log4.genres.str.split('|').tolist()).stack().value_counts().head(1)
display(log4)


answer_ls.append(1)
# Out:
# Drama    560
# dtype: int64

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
log5 = data['director'].value_counts()
display(log5)

answer_ls.append(3)
# Out:
# Steven Soderbergh         13
# Ridley Scott              12
# Clint Eastwood            12
# Steven Spielberg          10
# Shawn Levy                10
#                           ..
# Phil Traill                1
# Davis Guggenheim           1
# Jonas Elmer                1
# Klay Hall                  1
# Andrew Erwin|Jon Erwin     1
# Name: director, Length: 958, dtype: int64

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
log6 = data.query('profit > 0')
log6 = log6['director'].value_counts()
display(log6)

answer_ls.append(4)
# Out:
# Ridley Scott               12
# Clint Eastwood             10
# Steven Soderbergh          10
# Steven Spielberg           10
# Shawn Levy                  9
#                            ..
# Chris Rock                  1
# Hoyt Yeatman                1
# Mike McCoy|Scott Waugh      1
# Nanette Burstein            1
# Cody Cameron|Kris Pearn     1
# Name: director, Length: 774, dtype: int64

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
log7 = data[(data.profit > 0)]
log7 = log7.groupby(['director']).sum().sort_values(by=['profit'], ascending=False)

display(log7)

answer_ls.append(5)
# Out:
#                    popularity      budget     revenue  runtime  vote_count  \
# director
# Peter Jackson            45.7  1288000000  6490593685     1355       31197
# David Yates              20.5   775000000  4154295625      567       13819
# Christopher Nolan        61.6  1005000000  4167548502     1135       41561
# J.J. Abrams              24.0   740000000  3579169916      633       14962
# Michael Bay              15.2  1126000000  3886938960     1209       13854
# ...                       ...         ...         ...      ...         ...
# John Bonito               0.6    20000000    22165608       92          94
# Joe Nussbaum              0.5     8000000    10130000      104          78
# Bill Paxton               0.6    11000000    13110448      100         136
# Sarah Gavron              0.9    14000000    16002420      106         231
# Christian Alvart          1.0    27000000    29000000      109         298
#
#                    vote_average  release_year      profit
# ...

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
# Вычисляю сколько актеров в фильме
log8 = pd.DataFrame(data.cast.str.split('|'))

# display(log8)

count_actors_per_firm = {}
actors_per_firm = {}

for id, item in log8.items():
    for i, actor in item.items():
#         actors_per_firm.update({i: actor})
#         count_actors_per_firm.update({i: len(actor)})
#         display(len(actor))
        data['count_actors_per_film'] = data.apply(lambda count: len(actor), axis = 1)

# Вычисляю прибыль в фильме на одного актера
data['profit_per_actor'] = data.apply(lambda ppa: ppa.revenue / ppa.count_actors_per_film, axis = 1)

# display(data[['cast', 'profit', 'count_actors_per_film', 'profit_per_actor']])

# display(data.iloc[0]['cast'])

# Группирую дата-фрейма по количеству фильмов, в которых снимался каждый актер    
log9 = pd.DataFrame(data.cast.str.split('|').tolist()).stack().value_counts()

display(len(log9))

display(log9)

# Разбиваю каждый фильм по актерам    
log10 = pd.DataFrame(data.cast.str.split('|').tolist()).stack()

display(len(log10))

# Формируем список всех актеров, которые снимаются в фильмах
actors_list = []

for name, count_films in log9.items():
    actors_list.append(name)
    
# Формируем словарь, где показываем, какой актер сколько заработал (в каждом фильме, если он там принимал участие)
actors_profit = {}
    
# for actor in actors_list:
for name in actors_list:
    counter = 0
    while counter < len(data):
        if name in data.iloc[counter]['cast']:

            if actors_profit.get(name) == None:
                revenue = data.iloc[counter]['profit_per_actor']
            else:
                revenue = actors_profit[name] + data.iloc[counter]['profit_per_actor']
            actors_profit.update({name: revenue})


        counter += 1

print(actors_profit)        
display(len(actors_profit))
# Out:
# 3408
# Nicolas Cage          27
# Samuel L. Jackson     27
# Matt Damon            26
# Robert De Niro        26
# Bruce Willis          25
#                       ..
# Nathalie Kelley        1
# John C. McGinley       1
# Conrad Vernon          1
# Eddie J. Fernandez     1
# John Shrapnel          1
# Length: 3408, dtype: int64
# 9443
# ...

# %%
pd.options.display.float_format = '{:,.1f}'.format
log11 = pd.DataFrame.from_dict(actors_profit, orient='index',
                       columns=['revenue'])

display(log11.sort_values(by=['revenue'], ascending=False))

answer_ls.append(1)
# Out:
#                          revenue
# Emma Watson      1,631,849,119.4
# Ian McKellen     1,604,475,155.4
# Daniel Radcliffe 1,572,598,056.2
# Rupert Grint     1,539,327,658.0
# Johnny Depp      1,484,283,400.0
# ...                          ...
# Tiger Hu Chen          410,988.2
# Karen Mok              410,988.2
# Steven Dasz            410,988.2
# Jeremy Marinas         410,988.2
# Sean Pertwee           406,633.0
#
# [3408 rows x 1 columns]

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
log12 = data.query('release_year == 2012')

# display(log12)

# Вычисляю сколько актеров в фильме
log13 = pd.DataFrame(log12.cast.str.split('|'))

# display(log8)

count_actors_per_firm = {}
actors_per_firm = {}

for id, item in log13.items():
    for i, actor in item.items():
#         actors_per_firm.update({i: actor})
#         count_actors_per_firm.update({i: len(actor)})
#         display(len(actor))
        data['count_actors_per_film'] = data.apply(lambda count: len(actor), axis = 1)

# Вычисляю прибыль в фильме на одного актера
data['profit_per_actor'] = data.apply(lambda ppa: ppa.profit / ppa.count_actors_per_film, axis = 1)

# display(data[['cast', 'profit', 'count_actors_per_film', 'profit_per_actor']])

# display(data.iloc[0]['cast'])

# Группирую дата-фрейма по количеству фильмов, в которых снимался каждый актер    
log14 = pd.DataFrame(log12.cast.str.split('|').tolist()).stack().value_counts()

display(len(log14))

display(log14)

# Разбиваю каждый фильм по актерам    
log15 = pd.DataFrame(log12.cast.str.split('|').tolist()).stack()

display(len(log15))

# Формируем список всех актеров, которые снимаются в фильмах
actors_list = []

for name, count_films in log14.items():
    actors_list.append(name)
    
# Формируем словарь, где показываем, какой актер сколько заработал (в каждом фильме, если он там принимал участие)
actors_profit = {}
    
# for actor in actors_list:
for name in actors_list:
    counter = 0
    while counter < len(log12):
        if name in log12.iloc[counter]['cast']:

            if actors_profit.get(name) == None:
                revenue = log12.iloc[counter]['profit_per_actor']
            else:
                revenue = actors_profit[name] + log12.iloc[counter]['profit_per_actor']
            actors_profit.update({name: revenue})


        counter += 1

print(actors_profit)        
display(len(actors_profit))
# Out:
# 466
# Bruce Willis         5
# Channing Tatum       4
# Anna Kendrick        4
# Bryan Cranston       4
# Chris Hemsworth      4
#                     ..
# Paula Patton         1
# Javier Bardem        1
# Tom Everett Scott    1
# Emilio Rivera        1
# Olivia Munn          1
# Length: 466, dtype: int64
# 555
# ...

# %%
pd.options.display.float_format = '{:,.1f}'.format
log16 = pd.DataFrame.from_dict(actors_profit, orient='index',
                       columns=['revenue'])

display(log16.sort_values(by=['revenue'], ascending=True))

answer_ls.append(3)
# Out:
#                         revenue
# Kirsten Dunst     -13,621,841.4
# Timothy Spall     -10,378,705.0
# Heidi Hawkins     -10,378,705.0
# James Kidnie      -10,378,705.0
# Malin Ã…kerman     -8,746,701.8
# ...                         ...
# Chris Evans       259,911,582.0
# Robert Downey Jr. 259,911,582.0
# Mark Ruffalo      259,911,582.0
# Denis Leary       263,892,127.8
# Chris Hemsworth   308,490,154.6
#
# [466 rows x 1 columns]

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
budget_median = data['budget'].median()

display(budget_median)


log17 = data.query('budget > @budget_median').sort_values(by=['budget'], ascending=False)
# log18 = log17.groupby(['original_title']).sum().sort_values(by=['budget'], ascending=False)

log19 = pd.DataFrame(log17.cast.str.split('|').tolist()).stack().value_counts().head(1)

# log6 = log6['director'].value_counts()
display(log19)

answer_ls.append(3)
# Out:
# 38000000.0
# Matt Damon    22
# dtype: int64

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
############# Всякие тестовые штуки ##################

# log20 = pd.DataFrame(data.cast.str.split('|').tolist()).stack().value_counts()
# log21 = pd.DataFrame(data.genres.str.split('|').tolist()).stack().value_counts()

# Список актеров
actors_list = pd.DataFrame(data.cast.str.split('|').tolist()).stack().unique().tolist()

# Список жанров
genres_list = pd.DataFrame(data.genres.str.split('|').tolist()).stack().unique().tolist()

# Список жанров из конкретной серии (строчки)
genres_from_0 = pd.DataFrame(data.iloc[0].genres.split('|')).stack().value_counts()

# a = data.iloc[0].cast
# a_new = a.split('|')

# Прибыль по каждому фильму списком
profit_list = data['profit'].tolist()

actors_profit_df = pd.DataFrame({'profit': 0.}, index = actors_list)

actors_profit_df.loc['Nicolas Cage'] = data[data.cast.str.contains("Nicolas Cage")].profit.sum()

actors_profit_df.sort_values(by=['profit'], ascending=False)

############# Всякие тестовые штуки завершил. Делаю функцию для решения задачи ##################

# ДатаСет с фильмами, в которых принимал участие Nicolas Cage
nicolas_cage_films_df = data[data.cast.str.contains("Nicolas Cage")]

# Создам пустой список, в который буду складывать все жанры, с которыми работал Nicolas Cage
nicolas_genres_list = []

def genres_of_actor(data):
    
   
    for i in range(0, len(nicolas_cage_films_df)):
        c =  data.iloc[i].cast.split('|')
        

        if 'Nicolas Cage' in c:
            genres_new = data.iloc[i].genres.split('|')

            for g_n in genres_new:
                nicolas_genres_list.append(g_n)
                    
genres_of_actor(nicolas_cage_films_df)

nicolas_genres = Counter(nicolas_genres_list)

display(nicolas_genres.most_common())

answer_ls.append(2)
# Out:
# [('Action', 17),
#  ('Thriller', 15),
#  ('Drama', 12),
#  ('Crime', 10),
#  ('Fantasy', 8),
#  ('Adventure', 7),
#  ('Comedy', 6),
#  ('Science Fiction', 4),
#  ('Mystery', 3),
#  ('Animation', 3),
#  ('Family', 3),
#  ('History', 2),
#  ('War', 1),
#  ('Horror', 1),
#  ('Romance', 1)]

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
############# Всякие тестовые штуки завершил. Делаю функцию для решения задачи ##################

# Список студий
production_companies_list = pd.DataFrame(data.production_companies.str.split('|').tolist()).stack().unique().tolist()

display(len(production_companies_list))
# display(production_companies_list)

# Создам пустой список, в который буду складывать все студии, которые работали над фильмами
production_companies_list_split = []

def counter_production_companies(data):    
   
    for i in range(0, len(data)):
        pc_row =  data.iloc[i].production_companies.split('|')
        
        for pc in pc_row:
            production_companies_list_split.append(pc)
                    
counter_production_companies(data)

production_companies_list = Counter(production_companies_list_split)

display(production_companies_list.most_common())

answer_ls.append(1)
# Out:
# 1772
# [('Universal Pictures', 173),
#  ('Warner Bros.', 168),
#  ('Paramount Pictures', 122),
#  ('Columbia Pictures', 117),
#  ('Twentieth Century Fox Film Corporation', 109),
#  ('Relativity Media', 99),
#  ('New Line Cinema', 88),
#  ('Walt Disney Pictures', 82),
#  ('Village Roadshow Pictures', 63),
#  ('DreamWorks SKG', 62),
#  ('Touchstone Pictures', 58),
#  ('Regency Enterprises', 49),
#  ('Metro-Goldwyn-Mayer (MGM)', 48),
#  ('Columbia Pictures Corporation', 47),
#  ('Dune Entertainment', 44),
#  ('Summit Entertainment', 41),
#  ('Miramax Films', 39),
#  ('Dimension Films', 37),
#  ('Lionsgate', 35),
#  ('Fox 2000 Pictures', 35),
#  ('Legendary Pictures', 34),
#  ('Spyglass Entertainment', 32),
#  ('Screen Gems', 31),
#  ('Revolution Studios', 30),
#  ('Original Film', 29),
#  ('New Regency Pictures', 28),
#  ('The Weinstein Company', 28),
#  ('Working Title Films', 27),
#  ('DreamWorks Animation', 26),
#  ('Imagine Entertainment', 25),
#  ('Scott Free Productions', 24),
# ...

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
############# Всякие тестовые штуки завершил. Делаю функцию для решения задачи ##################

# Фильмы, вышедшие в 2015 году
films_from_2015 = data[data['release_year'] == 2015]

# Список студий
production_companies_list = pd.DataFrame(films_from_2015.production_companies.str.split('|').tolist()).stack().unique().tolist()

display(len(production_companies_list))
display(production_companies_list)

# Создам пустой список, в который буду складывать все студии, которые работали над фильмами
production_companies_list_split = []

def counter_production_companies(data):    
   
    for i in range(0, len(data)):
        pc_row =  data.iloc[i].production_companies.split('|')
        
        for pc in pc_row:
            production_companies_list_split.append(pc)
                    
counter_production_companies(films_from_2015)

production_companies_list = Counter(production_companies_list_split)

display(production_companies_list.most_common())

answer_ls.append(4)
# Out:
# 246
# ['Universal Studios',
#  'Amblin Entertainment',
#  'Legendary Pictures',
#  'Fuji Television Network',
#  'Dentsu',
#  'Village Roadshow Pictures',
#  'Kennedy Miller Productions',
#  'Summit Entertainment',
#  'Mandeville Films',
#  'Red Wagon Entertainment',
#  'NeoReel',
#  'Lucasfilm',
#  'Truenorth Productions',
#  'Bad Robot',
#  'Universal Pictures',
#  'Original Film',
#  'Media Rights Capital',
#  'One Race Films',
#  'Regency Enterprises',
#  'Appian Way',
#  'CatchPlay',
#  'Anonymous Content',
#  'New Regency Pictures',
#  'Paramount Pictures',
#  'Skydance Productions',
#  'Twentieth Century Fox Film Corporation',
#  'Scott Free Productions',
#  'Mid Atlantic Films',
#  'International Traders',
#  'TSG Entertainment',
#  'Illumination Entertainment',
#  'Walt Disney Pictures',
#  'Pixar Animation Studios',
#  'Walt Disney Studios Motion Pictures',
#  'Columbia Pictures',
#  'Danjaq',
#  'B24',
#  'Dune Entertainment',
#  'Anarchos Productions',
#  'Warner Bros.',
# ...

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
############# Всякие тестовые штуки ##################

# Список студий, которые работают в жанре комедия
# production_companies_list = pd.DataFrame(data[data.genres.str.contains("Comedy")].production_companies.str.split('|').tolist()).stack().unique().tolist()

# Список жанров
# genres_list = pd.DataFrame(data.genres.str.split('|').tolist()).stack().unique().tolist()

# Список жанров из конкретной серии (строчки)
# genres_from_0 = pd.DataFrame(data.iloc[0].genres.split('|')).stack().value_counts()

# a = data.iloc[0].cast
# a_new = a.split('|')

# Прибыль по каждому фильму списком
# profit_list = data['profit'].tolist()

# production_companies_profit_df = pd.DataFrame({'profit': 0.}, index = production_companies_list)

# production_companies_profit_df.loc['Comedy'] = data[data.genres.str.contains("Comedy")].profit.sum()

# production_companies_profit_df.sort_values(by=['profit'], ascending=False)

# display(len(production_companies_list))
# display(production_companies_list)

############# Всякие тестовые штуки завершил. Делаю функцию для решения задачи ##################

data['count_studios_per_film'] = data.apply(lambda count: len(count.production_companies.split('|')) , axis = 1)

data['profit_per_studio'] = data.apply(lambda count: count.profit / count.count_studios_per_film, axis = 1)

# Список студий, которые работают в жанре комедия
films_comedy_list = data[data.genres.str.contains("Comedy")]


# Создам пустой словарь, в который буду складывать все студии, которые работали в жанре комедия, и их прибыль суммарную по каждой студии
production_companies_from_comedy ={}

def counter_production_companies(data):    
   
    for i in range(0, len(data)):
        companies =  data.iloc[i].production_companies.split('|')
        profit_per_studio =  data.iloc[i].profit_per_studio
        
        for company in companies:
            if company in production_companies_from_comedy:
                production_companies_from_comedy[company] += profit_per_studio
            else:
                production_companies_from_comedy[company] = profit_per_studio
        

                    
counter_production_companies(films_comedy_list)

sorted_by_value = sorted(production_companies_from_comedy.items(), key=lambda kv: kv[1], reverse=True)

display(sorted_by_value)


# Если в будущем захочу отсортировать через Counter общее кол-во снятых фильмов каждой студией, то вот придумал решение.
# # Создам пустой список, в который буду складывать все студии, которые работали над фильмами в жанре комедии
# production_companies_list_split = []

# def counter_production_companies(data):    
   
#     for i in range(0, len(data)):
#         pc_row =  data.iloc[i].production_companies.split('|')
        
#         for pc in pc_row:
#             production_companies_list_split.append(pc)
                    
# counter_production_companies(films_comedy_list)

# production_companies_list = Counter(production_companies_list_split)

# display(production_companies_list.most_common())

answer_ls.append(2)
# Out:
# [('Walt Disney Pictures', 3660158305.65),
#  ('Universal Pictures', 3459196021.266667),
#  ('DreamWorks Animation', 3145966021.5),
#  ('Columbia Pictures', 2227535621.833333),
#  ('Twentieth Century Fox Film Corporation', 2118873640.1000001),
#  ('Pixar Animation Studios', 1976981159.1666667),
#  ('New Line Cinema', 1489653688.533333),
#  ('Twentieth Century Fox Animation', 1399523667.7666667),
#  ('Blue Sky Studios', 1398229463.1666667),
#  ('Paramount Pictures', 1231266738.3666666),
#  ('Warner Bros.', 1117568074.2166665),
#  ('DreamWorks SKG', 1005885782.1500001),
#  ('Illumination Entertainment', 988746423.5),
#  ('Relativity Media', 788965807.5999999),
#  ('Happy Madison Productions', 731226576.5333334),
#  ('Fox 2000 Pictures', 725367637.05),
#  ('Walt Disney Animation Studios', 724326452.5),
#  ('Sony Pictures Animation', 697536050.9666668),
#  ('Dimension Films', 673533997.6666666),
#  ('Apatow Productions', 631818131.8333333),
#  ('Pacific Data Images (PDI)', 578882194.0),
# ...

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
############# Всякие тестовые штуки завершил. Делаю функцию для решения задачи ##################

data['count_studios_per_film'] = data.apply(lambda count: len(count.production_companies.split('|')) , axis = 1)

data['profit_per_studio'] = data.apply(lambda count: count.profit / count.count_studios_per_film, axis = 1)
    
# Фильмы, вышедшие в 2012 году
films_from_2012 = data[(data['release_year'] == 2012)]

   
# Создам пустой словарь, в который буду складывать все студии, которые работали над фильмами в 2012 году, и их прибыль суммарную по каждой студии
production_companies_and_profit ={}

def counter_production_companies(data):    
   
    for i in range(0, len(data)):
        companies =  data.iloc[i].production_companies.split('|')
        profit_per_studio =  data.iloc[i].profit_per_studio
        
        for company in companies:
            if company in production_companies_and_profit:
                production_companies_and_profit[company] += profit_per_studio
            else:
                production_companies_and_profit[company] = profit_per_studio
        

                    
counter_production_companies(films_from_2012)

sorted_by_value = sorted(production_companies_and_profit.items(), key=lambda kv: kv[1], reverse=True)

display(sorted_by_value)


answer_ls.append(3)
# Out:
# [('Columbia Pictures', 1555986050.3),
#  ('Marvel Studios', 1299557910.0),
#  ('Universal Pictures', 790266654.8000001),
#  ('DreamWorks Animation', 763862944.0),
#  ('Blue Sky Studios', 391122391.0),
#  ('Twentieth Century Fox Animation', 391122391.0),
#  ('Summit Entertainment', 368495447.03333336),
#  ('The Weinstein Company', 351710835.6666667),
#  ('New Line Cinema', 340108082.5),
#  ('Lionsgate', 339656006.8),
#  ('Warner Bros.', 317830667.2166667),
#  ('Color Force', 308105346.0),
#  ('Walt Disney Animation Studios', 306222889.0),
#  ('Metro-Goldwyn-Mayer (MGM)', 304441131.8),
#  ('Relativity Media', 255762005.54999995),
#  ('WingNut Films', 255667856.0),
#  ('Legendary Pictures', 237960321.75),
#  ('Sunswept Entertainment', 236333333.33333334),
#  ('Temple Hill Entertainment', 236333333.33333334),
#  ('Walt Disney Pictures', 215294392.83333334),
#  ('DC Entertainment', 207760321.75),
#  ('Syncopy', 207760321.75),
#  ('Dune Entertainment', 198595848.5),
# ...

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
# Фильмы от Paramount Pictures

paramount_pictures_films_list = data[data.production_companies.str.contains("Paramount Pictures")]

display(paramount_pictures_films_list.sort_values(by=['profit'], ascending=True))


answer_ls.append(1)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 926   tt0267626         0.7  100000000    35168966
# 1124  tt0300556         1.0   80000000    19480739
# 1723  tt0435705         1.1   70000000    18211013
# 1624  tt0375173         0.9   60000000    13395939
# 1632  tt0315297         0.8   50000000    25195000
# ...         ...         ...        ...         ...
# 731   tt1229238         3.0  145000000   694713380
# 1739  tt0418279         0.9  150000000   709709780
# 604   tt0367882         3.2  185000000   786636033
# 317   tt1055369         0.8  150000000   836297228
# 829   tt1399103         0.8  195000000  1123746996
#
#                                          original_title  \
# 926                                K-19: The Widowmaker
# 1124                                           Timeline
# 1723                                               Next
# 1624                                              Alfie
# 1632                                            Twisted
# ...

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
df = pd.read_csv('input/data.csv', 
                 parse_dates=['release_date']
                )
df['release_month'] = df.release_date.dt.month
df['release_year'] = df.release_date.dt.year

df['profit'] = df.apply(lambda row: row.revenue - row.budget, axis = 1)

df['profit_per_actor'] = df.apply(lambda ppa: ppa.profit / len(ppa.cast.split('|')), axis = 1)

df['count_studios_per_film'] = df.apply(lambda count: len(count.production_companies.split('|')), axis = 1)

df['profit_per_studio'] = df.apply(lambda count: count.profit / count.count_studios_per_film, axis = 1)

# display(df.sort_values(by=['profit'], ascending=False))

df_new = df.groupby(['release_year']).sum().sort_values(by=['profit'], ascending=False)


display(df_new)

answer_ls.append(5)
# Out:
#               popularity      budget      revenue  runtime  vote_count  \
# release_year
# 2015               412.8  6780630004  25449202382    13355      143377
# 2014               374.5  7008050000  23405862953    13444      155491
# 2012               194.3  7002000000  23079001687    12145      150430
# 2013               216.4  7970620000  23213799791    15039      167162
# 2011               205.1  7946550531  22676791872    15355      113342
# 2009               175.3  6838046652  20261791024    14187       97625
# 2010               179.2  7965000000  21082292530    13692      106841
# 2008               158.9  6588900000  18252781990    12979       84574
# 2007               146.1  6596495000  18162406801    14305       72225
# 2004               142.9  6029250000  15663430720    12014       66099
# 2003               129.9  5117300000  14346123312    10623       57598
# 2002               127.0  5134000000  14136361487    11528       54743
# ...

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
# ДатаСет с фильмами, которые снимала Warner Bros
warner_bros_films_df = data[data.production_companies.str.contains("Warner Bros")]



warner_bros_films_df = warner_bros_films_df.groupby(['release_year']).sum().sort_values(by=['profit'], ascending=False)

display(warner_bros_films_df)


answer_ls.append(1)
# Out:
#               popularity      budget     revenue  runtime  vote_count  \
# release_year
# 2014                63.9   947600000  3243064519     1576       24855
# 2007                22.4   982000000  3183675217     1721       15760
# 2008                24.0   916000000  3050595031     1366       17455
# 2010                26.4  1034000000  3008712985     1421       20286
# 2011                23.5   974000000  2845393682     1248       15559
# 2003                17.6   890000000  2745493377     1085        8516
# 2009                24.3   915500000  2737954136     1305       16473
# 2013                22.3   963500000  2599953400     1100       19352
# 2004                21.1  1100000000  2731933725     1624       10964
# 2005                22.5   861000000  2412980298     1193       13203
# 2001                21.1   923000000  2266545668     1571       10494
# 2012                12.6   611500000  1869520056      579       11729
# ...

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
# Создам пустой словарь, в который буду складывать месяца и их прибыль суммарную по каждой студии
month_and_profit ={}

def counter_month_and_profit(data):    
   
    for i in range(0, len(data)):
        month =  data.iloc[i].release_month

        if month in month_and_profit:
            month_and_profit[month] += 1
        else:
            month_and_profit[month] = 1
        

                    
counter_month_and_profit(df)

sorted_by_value = sorted(month_and_profit.items(), key=lambda kv: kv[1], reverse=True)

display(sorted_by_value)


answer_ls.append(4)
# Out:
# [(9, 227),
#  (12, 191),
#  (10, 186),
#  (8, 161),
#  (3, 156),
#  (4, 149),
#  (6, 147),
#  (11, 146),
#  (7, 142),
#  (5, 140),
#  (2, 135),
#  (1, 110)]

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
sum_films_from_summer_months = month_and_profit[6] + month_and_profit[7] + month_and_profit[8]
display(sum_films_from_summer_months)

# answer_ls.append(1)
# Out:
# 450

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
# Создам пустой словарь, в который буду складывать месяца и режиссеров
month_and_director ={}

def counter_month_and_director(data):    
   
    for i in range(0, len(data)):
        month =  data.iloc[i].release_month
        directors = data.iloc[i].director.split('|')
        
        if month == 1 or month == 2 or month == 12:
        
            for director in directors:

                if director in month_and_director:
                    month_and_director[director] += 1
                else:
                    month_and_director[director] = 1
        

                    
counter_month_and_director(df)

sorted_by_value = sorted(month_and_director.items(), key=lambda kv: kv[1], reverse=True)

display(sorted_by_value)

answer_ls.append(5)
# Out:
# [('Peter Jackson', 7),
#  ('Clint Eastwood', 6),
#  ('Steven Soderbergh', 6),
#  ('Shawn Levy', 4),
#  ('Nancy Meyers', 4),
#  ('Martin Scorsese', 4),
#  ('Adam Shankman', 4),
#  ('Ridley Scott', 3),
#  ('Rob Marshall', 3),
#  ('Tim Burton', 3),
#  ('Steve Carr', 3),
#  ('Patrick Lussier', 3),
#  ('Donald Petrie', 3),
#  ('Marc Lawrence', 3),
#  ('Lasse HallstrÃ¶m', 3),
#  ('Edward Zwick', 3),
#  ('Jason Friedberg', 3),
#  ('Aaron Seltzer', 3),
#  ('Peter Farrelly', 3),
#  ('Steven Spielberg', 3),
#  ('Wayne Wang', 3),
#  ('Quentin Tarantino', 2),
#  ('Adam McKay', 2),
#  ('Michael Mann', 2),
#  ('Glenn Ficarra', 2),
#  ('John Requa', 2),
#  ('Pierre Morel', 2),
#  ('Wes Anderson', 2),
#  ('Paul Thomas Anderson', 2),
#  ('Jaume Collet-Serra', 2),
#  ('George Clooney', 2),
#  ('Shana Feste', 2),
#  ('Ken Kwapis', 2),
#  ('Henry Selick', 2),
#  ('P.J. Hogan', 2),
#  ('David S. Goyer', 2),
#  ('Paul McGuigan', 2),
#  ('Marcus Nispel', 2),
#  ('Andrzej Bartkowiak', 2),
# ...

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
df_new2 = df.pivot_table('profit', index='release_month', columns='release_year', aggfunc='sum').idxmax()


# Ответ практически готов - можно для плезиру .value_counts() или вообще .value_counts().idxmax() применить.

display(df_new2.value_counts().idxmax())


answer_ls.append(2)
# Out:
# 6

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
# %%time
import time
import pprint

# Создам пустой словарь и вложенный словарь, в который буду складывать название студии и длину названия фильма с привязкой к строке записи в датафрейме
pc_and_len_title ={}

def counter_pc_and_len_title(data):    
   
    for i in range(0, len(df)):
        pcs =  df.iloc[i].production_companies.split('|')
        length = len(df.iloc[i].original_title)
        
        
        for pc in pcs:
            
            if i in pc_and_len_title:
                pc_and_len_title[i].update({pc: length})
            else:
                pc_and_len_title[i] = {pc: length}

        

                    
counter_pc_and_len_title(df)

df_31 = pd.DataFrame.from_dict(pc_and_len_title, orient='index')

# pp = pprint.PrettyPrinter(indent=4)
# pp.pprint(pc_and_len_title)

display(df_31.mean().sort_values())

answer_ls.append(5)
# Out:
# Ixtlan Productions            2.0
# Global Entertainment Group    2.0
# XM2 Productions               2.0
# Everest Entertainment         3.0
# Berlanti Productions          3.0
#                              ...
# Museum Canada Productions    46.0
# Polsky Films                 46.0
# Dos Corazones                47.0
# Jim Henson Company, The      59.0
# Four By Two Productions      83.0
# Length: 1772, dtype: float64
# Wall time: 1.06 s

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
# %%time
import time
import pprint

# Создам пустой словарь и вложенный словарь, в который буду складывать название студии и длину названия фильма с привязкой к строке записи в датафрейме
pc_and_count_word_in_title ={}

def counter_pc_and_len_title(data):    
   
    for i in range(0, len(df)):
        pcs =  df.iloc[i].production_companies.split('|')
        temp_words_list = df.iloc[i].original_title.split(' ')
        length = len(temp_words_list)
        
        
        for pc in pcs:
            
            if df.iloc[i].original_title in pc_and_count_word_in_title:
                pc_and_count_word_in_title[df.iloc[i].original_title].update({pc: length})
            else:
                pc_and_count_word_in_title[df.iloc[i].original_title] = {pc: length}

        

                    
counter_pc_and_len_title(df)

df_32 = pd.DataFrame.from_dict(pc_and_count_word_in_title, orient='index')

# pp = pprint.PrettyPrinter(indent=4)
# pp.pprint(pc_and_count_word_in_title)

display(df_32.mean().sort_values())

answer_ls.append(5)
# Out:
# Jolie Pas                  1.0
# Le Pacte                   1.0
# Filmgate Films             1.0
# Saints LA                  1.0
# Art Pictures Studio        1.0
#                           ...
# Polsky Films               9.0
# Dos Corazones              9.0
# The Saul Zaentz Company    9.0
# Jim Henson Company, The   10.0
# Four By Two Productions   12.0
# Length: 1772, dtype: float64
# Wall time: 2.93 s

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
# %%time
import time
import pprint

# Создам пустой словарь и вложенный словарь, в который буду складывать название студии и длину названия фильма с привязкой к строке записи в датафрейме
count_unique_word_in_title = []


def counter_unique_words_in_title(data):    
   
    for i in range(0, len(df)):
        title = df.iloc[i].original_title
        temp_words_list = df.iloc[i].original_title.lower().split(' ')
        
        for word in temp_words_list:
            
            count_unique_word_in_title.append(word)
        

                    
counter_unique_words_in_title(df)

new_list = set(count_unique_word_in_title)

new_list.remove('-')

display(len(new_list))

answer_ls.append(3)
# Out:
# 2461
# Wall time: 587 ms

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
# Обратимся к квантилям
# Т.е. введем условие, что df['vote_average'] > df.quantile(0.99, numeric_only=True)['vote_average']

the_most_popularity_films = df[df['vote_average'] > df.quantile(0.99, numeric_only=True)['vote_average']][['vote_average','original_title']].sort_values(by='vote_average', ascending=False)

display(the_most_popularity_films)


answer_ls.append(1)
# Out:
#       vote_average                                 original_title
# 600            8.1                                The Dark Knight
# 9              8.0                                     Inside Out
# 34             8.0                                           Room
# 118            8.0                                   Interstellar
# 125            8.0                             The Imitation Game
# 119            7.9                        Guardians of the Galaxy
# 128            7.9                                      Gone Girl
# 138            7.9                       The Grand Budapest Hotel
# 370            7.9                                      Inception
# 873            7.9                                    The Pianist
# 1082           7.9  The Lord of the Rings: The Return of the King
# 1184           7.9                        The Wolf of Wall Street
# 1192           7.9                               12 Years a Slave
# ...

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
# %%time
import time

# Создам пустой список, в который буду складывать пары актеров по каждому фильму
pairs_actors = []

def pairs_actors_searcher(data):    
   
    for i in range(0, len(df)):
        actors =  df.iloc[i].cast.split('|')

        for item in combinations(actors, 2):
            pairs_actors.append(' & '.join(item))
        
        
pairs_actors_searcher(df)

pairs_actors_counter = Counter(pairs_actors)

display(pairs_actors_counter.most_common())


answer_ls.append(5)
# Out:
# [('Daniel Radcliffe & Rupert Grint', 8),
#  ('Daniel Radcliffe & Emma Watson', 8),
#  ('Rupert Grint & Emma Watson', 7),
#  ('Ben Stiller & Owen Wilson', 6),
#  ('Johnny Depp & Helena Bonham Carter', 6),
#  ('Adam Sandler & Kevin James', 5),
#  ('Hugh Jackman & Ian McKellen', 5),
#  ('Kristen Stewart & Robert Pattinson', 5),
#  ('Kristen Stewart & Taylor Lautner', 5),
#  ('Robert Pattinson & Taylor Lautner', 5),
#  ('Jennifer Lawrence & Josh Hutcherson', 4),
#  ('Jennifer Lawrence & Liam Hemsworth', 4),
#  ('Jennifer Lawrence & Woody Harrelson', 4),
#  ('Josh Hutcherson & Liam Hemsworth', 4),
#  ('Josh Hutcherson & Woody Harrelson', 4),
#  ('Liam Hemsworth & Woody Harrelson', 4),
#  ('Tobin Bell & Costas Mandylor', 4),
#  ('Tobin Bell & Betsy Russell', 4),
#  ('Costas Mandylor & Betsy Russell', 4),
#  ('Vin Diesel & Jordana Brewster', 4),
#  ('Paul Walker & Jordana Brewster', 4),
#  ('Mike Myers & Eddie Murphy', 4),
#  ('Mike Myers & Cameron Diaz', 4),
# ...

# %% [markdown]
# # 36. У какого из режиссеров выше вероятность выпустить фильм в прибыли? (5 баллов)101
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
directors_list = ['Quentin Tarantino', 'Steven Soderbergh', 'Robert Rodriguez', 'Christopher Nolan', 'Clint Eastwood']

def all_and_profitable_films_by_director(df, director):

    films_of_qt = df[df['director'] == director]
    profitable_films_of_qt = df[(df['director'] == director) & (df['profit'] > 0)]
    display(director)
    display(len(films_of_qt))
    display(len(profitable_films_of_qt))
    display(len(profitable_films_of_qt) / len(films_of_qt))

for director in directors_list:
    
    all_and_profitable_films_by_director(df, director)



answer_ls.append(4)
# Out:
# 'Quentin Tarantino'
# 5
# 5
# 1.0
# 'Steven Soderbergh'
# 13
# 10
# 0.7692307692307693
# 'Robert Rodriguez'
# 7
# 6
# 0.8571428571428571
# 'Christopher Nolan'
# 8
# 8
# 1.0
# 'Clint Eastwood'
# 12
# 10
# 0.8333333333333334

# %% [markdown]
# # Submission

# %%
len(answer_ls)
# Out:
# 0

# %%
pd.DataFrame({'Id':range(1,len(answer_ls)+1), 'Answer':answer_ls}, columns=['Id', 'Answer'])
# Out:
# Empty DataFrame
# Columns: [Id, Answer]
# Index: []
